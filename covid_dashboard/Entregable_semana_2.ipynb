# %%
# PYTHON INTERMEDIO PARA INGENIERÍA

## Avance semana 2

    #Nombres y Apellidos:  Karen Sofia Masache Astudillo
    #Profesor:              Santiago Quiñones
    #Fecha:                 16/12/2021


#Se adjunta data, visualizaciones iniciales, distribución en un archivo de jupyter.

# %% [markdown]
# 1.   La fuente de datos que se va a utilizar es: ECUACOVID: https://github.com/andrab/ecuacovid
# 2.   List item

# %%
import pandas as pd

df = pd.read_csv('sample_data/ecuacovid.csv')
df
# Out:
#      muestras  muestras_pcr  ...  rpc_uci_camas_ocupadas  created_at
# 0         129           129  ...                       0  13/03/2020
# 1         206           206  ...                       0  14/03/2020
# 2         273           273  ...                       0  15/03/2020
# 3         354           354  ...                       0  16/03/2020
# 4         762           762  ...                       0  17/03/2020
# ..        ...           ...  ...                     ...         ...
# 637   2088356       2067784  ...                      25  10/12/2021
# 638   2093188       2072616  ...                      29  11/12/2021
# 639   2096308       2075736  ...                      30  12/12/2021
# 640   2097763       2077191  ...                      30  13/12/2021
# 641   2101391       2080819  ...                      33  14/12/2021
#
# [642 rows x 76 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

df['muestras'].hist()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df['positivas_total'].hist()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df.plot(kind='scatter',x='muestras',y='muestras_pcr',color='black')
plt.show()

# %%
df.describe()
# Out:
#            muestras  ...  rpc_uci_camas_ocupadas
# count  6.420000e+02  ...              642.000000
# mean   9.511512e+05  ...                6.866044
# std    6.753362e+05  ...               16.087828
# min    1.290000e+02  ...                0.000000
# 25%    2.984060e+05  ...                0.000000
# 50%    8.820965e+05  ...                0.000000
# 75%    1.589439e+06  ...                0.000000
# max    2.101391e+06  ...              104.000000
#
# [8 rows x 75 columns]
